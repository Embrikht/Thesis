# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %%
current_directory = os.getcwd()
folder_path = os.path.join(current_directory, 'k2_full')
files_in_folder = [filename for filename in os.listdir(folder_path)]

# %%
accuracy_score_k2f = 0
number_of_experiments = len(files_in_folder)

for file in files_in_folder:
    path_to_file = os.path.join(folder_path, file)
    df_k2f = pd.read_csv(path_to_file)
    
    X = df_k2f[df_k2f.columns[:-1]].values
    y = df_k2f[df_k2f.columns[-1]].values

    # Splitting the set into training and test set following a 80% - 20% split (train_size=0.8)
    # Using seed (random state), shuffle the dataset (shuffle=True) and drawing equal number of samples for each label (stratify=y)
    X_train_2f, X_test_2f, y_train_2f, y_test_2f = train_test_split(X, y, random_state=1, train_size=0.8, shuffle=True, stratify=y)

    # Gaussian Näive Bayes
    nb_model = GaussianNB()
    nb_model_2f = nb_model.fit(X_train_2f, y_train_2f)
    y_pred_2f = nb_model_2f.predict(X_test_2f)
# Out:
#     Nr_packets_up  Nr_packets_down  Bytes_up  Bytes_down  Bursts  \
# 0              73              129      7362      189152     107
# 1              72              129      7243      190438     109
# 2              72              121      7231      178054      91
# 3              72              130      7255      193415     101
# 4              71              128      7143      190344      97
# 5              75              120      7304      176506      85
# 6              73              123      7657      181150     105
# 7              71              125      7143      184246     111
# 8              72              127      7231      185888     107
# 9              67              119      6791      176412      87
# 10             69              129      6975      191892     109
# 11             71              131      7017      193534     113
# 12             73              120      7331      179202     109
# 13             73              130      7350      189246     121
# 14             72              128      7243      191605     105
# 15             69              121      6979      179508     105
# 16             72              129      7231      190438      97
# 17             71              122      7029      181056     105
# 18             72              128      7243      190344     111
# 19             71              119      7155      176225      99
# 20            162              213     16149      319927     198
# 21            162              208     16227      312187     184
# 22            152              188     19939      266153     184
# 23            165              214     16447      322923     193
# 24            162              208     16399      315070     153
# 25            165              219     16478      329196     182
# 26            165              209     16635      315183     153
# 27            165              211     16579      316831     196
# 28            157              220     15539      330763     172
# 29            153              203     15071      304260     151
# 30            166              221     16727      329403     187
# 31            165              212     16463      319833     196
# 32            170              220     17035      330570     170
# 33            159              213     15939      319927     168
# 34            161              212     16083      318379     148
# 35            167              223     16695      336861     179
# 36            164              216     16363      324571     150
# 37            161              200     16075      296895     137
# 38            165              216     16578      321837     168
# 39            171              222     17596      335195     217
#
#     Bytes_in_bursts  Trace_time    Answer
# 0             79260    2.176631  2013_609
# 1             82138    0.388150  2013_609
# 2             66766    0.382455  2013_609
# 3             74453    0.391159  2013_609
# 4             71987    0.397366  2013_609
# 5             63451    1.328182  2013_609
# 6             76447    1.415735  2013_609
# 7             81192    0.388663  2013_609
# 8             79809    0.909367  2013_609
# 9             64948    0.382458  2013_609
# 10            82940    1.115194  2013_609
# 11            83969    0.391737  2013_609
# 12            82907    0.879158  2013_609
# 13            86651    2.961591  2013_609
# 14            79678    0.400886  2013_609
# 15            79060    0.397814  2013_609
# 16            71987    0.385589  2013_609
# 17            78891    0.390646  2013_609
# 18            83787    0.378361  2013_609
# 19            72517    0.385072  2013_609
# 20           156972    0.622592  2011_686
# 21           142845    0.535091  2011_686
# 22           135554    2.708160  2011_686
# 23           150806    0.530422  2011_686
# 24           119408    0.508469  2011_686
# 25           142494    0.536565  2011_686
# 26           116881    0.587317  2011_686
# 27           152861    0.540724  2011_686
# 28           132997    0.524789  2011_686
# 29           116130    1.813109  2011_686
# 30           146023    0.734709  2011_686
# 31           154095    0.535605  2011_686
# 32           131210    0.537589  2011_686
# 33           129673    0.535606  2011_686
# 34           114434    0.541173  2011_686
# 35           138207    0.536118  2011_686
# 36           115001    0.537590  2011_686
# 37           103625    1.609334  2011_686
# 38           127230    1.409590  2011_686
# 39           169432    0.535606  2011_686
